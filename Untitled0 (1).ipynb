# %%
import pandas as pd
link1='https://raw.githubusercontent.com/Myyn2304/pc3/refs/heads/main/Education%20expenditures.csv'
tabla1=pd.read_csv(link1)
link2='https://raw.githubusercontent.com/Myyn2304/pc3/refs/heads/main/Electricity%20-%20installed%20generating%20capacity.csv'
tabla2=pd.read_csv(link2)
link3='https://raw.githubusercontent.com/Myyn2304/pc3/refs/heads/main/Energy%20consumption%20per%20capita.csv'
tabla3=pd.read_csv(link3)
link4='https://raw.githubusercontent.com/Myyn2304/pc3/refs/heads/main/Reserves%20of%20foreign%20exchange%20and%20gold.csv'
tabla4=pd.read_csv(link4)

# %%
#no es necesario eliminar alguna columna pues todas son necesarias
#quitar el espacio de los nombres cambiandolo por _ no sin antes str.strip() quita los espacios al inicio y final
tabla1.columns=tabla1.columns.str.strip().str.replace(r'\s+', '_', regex=True)
tabla2.columns=tabla2.columns.str.strip().str.replace(r'\s+', '_', regex=True)
tabla3.columns=tabla3.columns.str.strip().str.replace(r'\s+', '_', regex=True)
tabla4.columns=tabla4.columns.str.strip().str.replace(r'\s+', '_', regex=True)
#poniendo la primera letra de país en mayuscula
tabla1.columns=tabla1.columns.str.title()
tabla2.columns=tabla2.columns.str.title()
tabla3.columns=tabla3.columns.str.title()
tabla4.columns=tabla4.columns.str.title()

# %%
#verificar que no haya datos faltantes
tabla1[tabla1.isnull().any(axis=1)]
tabla2[tabla2.isnull().any(axis=1)]
tabla3[tabla3.isnull().any(axis=1)]
tabla4[tabla4.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Name, Slug, Value, Date_Of_Information, Ranking, Region]
# Index: []

# %%
#viendo el tipo de cada dato para identificar incongruencias
tabla1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 197 non-null    object
#  1   Slug                 197 non-null    object
#  2   %_Of_Gdp             197 non-null    float64
#  3   Date_Of_Information  197 non-null    int64
#  4   Ranking              197 non-null    int64
#  5   Region               197 non-null    object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 9.4+ KB

# %%
#viendo el tipo de cada dato para identificar incongruencias
tabla2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 211 non-null    object
#  1   Slug                 211 non-null    object
#  2   Kw                   211 non-null    object
#  3   Date_Of_Information  211 non-null    int64
#  4   Ranking              211 non-null    int64
#  5   Region               211 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 10.0+ KB

# %%
#viendo el tipo de cada dato para identificar incongruencias
tabla3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 195 non-null    object
#  1   Slug                 195 non-null    object
#  2   Btu/Person           195 non-null    object
#  3   Date_Of_Information  195 non-null    int64
#  4   Ranking              195 non-null    int64
#  5   Region               195 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 9.3+ KB

# %%
#viendo el tipo de cada dato para identificar incongruencias
tabla4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 195 non-null    object
#  1   Slug                 195 non-null    object
#  2   Value                195 non-null    object
#  3   Date_Of_Information  195 non-null    int64
#  4   Ranking              195 non-null    int64
#  5   Region               195 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 9.3+ KB

# %%
#Como se observa el Dtype de las columnas Kw, Btu/person, Value debería ser numérico, así que vamos a modificarlo

# %%
# se observa que el unico problema en la tabla 2 columna kW son las ","
pd.unique(tabla2.Kw[~tabla2.Kw.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['2,949,000,000', '1,235,000,000', '499,136,000', '361,617,000',
#        '301,926,000', '275,658,000', '240,251,000', '161,988,000',
#        '151,463,000', '151,139,000', '130,366,000', '128,692,000',
#        '119,620,000', '114,749,000', '108,193,000', '106,281,000',
#        '105,586,000', '86,058,000', '85,725,000', '70,826,000',
#        '65,989,000', '64,806,000', '64,535,000', '60,297,000',
#        '59,982,000', '59,680,000', '55,971,000', '55,307,000',
#        '47,631,000', '44,462,000', '43,512,000', '41,100,000',
#        '39,238,000', '37,220,000', '33,493,000', '33,371,000',
#        '31,339,000', '29,174,000', '28,248,000', '27,624,000',
#        '26,782,000', '26,502,000', '25,409,000', '24,169,000',
#        '22,699,000', '22,612,000', '22,591,000', '21,802,000',
#        '21,053,000', '20,794,000', '20,294,000', '19,748,000',
#        '17,901,000', '16,164,000', '14,829,000', '14,615,000',
#        '13,300,000', '13,134,000', '12,939,000', '12,738,000',
# ...

# %%
# se observa que el unico problema en la tabla 3 columna Btu/person son las ","

pd.unique(tabla3['Btu/Person'][~tabla3['Btu/Person'].astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['814,308,000', '643,259,000', '554,202,000', '450,432,000',
#        '403,365,000', '389,848,000', '349,692,000', '311,599,000',
#        '296,586,000', '278,474,000', '261,142,000', '234,698,000',
#        '234,668,000', '224,858,000', '224,651,000', '223,158,000',
#        '206,961,000', '206,102,000', '190,416,000', '185,536,000',
#        '183,540,000', '172,936,000', '160,779,000', '153,952,000',
#        '150,555,000', '143,149,000', '142,102,000', '136,306,000',
#        '129,504,000', '127,582,000', '123,526,000', '122,737,000',
#        '121,647,000', '120,457,000', '120,211,000', '116,811,000',
#        '113,837,000', '113,805,000', '113,163,000', '112,437,000',
#        '110,114,000', '107,188,000', '104,821,000', '104,502,000',
#        '104,409,000', '103,651,000', '102,171,000', '101,120,000',
#        '100,844,000', '99,578,000', '98,847,000', '98,513,000',
#        '96,797,000', '96,152,000', '94,280,000', '92,693,000',
# ...

# %%
# se observa que el unico problema en la tabla 4 columna kW son las "," y el "$"
pd.unique(tabla4.Value[~tabla4.Value.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['$3,265,000,000,000', '$1,160,000,000,000', '$822,130,000,000',
#        '$597,217,000,000', '$569,544,000,000', '$456,700,000,000',
#        '$436,769,000,000', '$425,554,000,000', '$409,457,000,000',
#        '$365,494,000,000', '$318,857,000,000', '$231,690,000,000',
#        '$227,760,000,000', '$221,944,000,000', '$217,261,000,000',
#        '$214,544,000,000', '$185,515,000,000', '$149,118,000,000',
#        '$148,569,000,000', '$141,988,000,000', '$120,600,000,000',
#        '$117,551,000,000', '$112,968,000,000', '$103,239,000,000',
#        '$96,792,000,000', '$95,251,000,000', '$92,238,000,000',
#        '$90,859,000,000', '$87,048,000,000', '$84,875,000,000',
#        '$84,154,000,000', '$81,242,000,000', '$80,592,000,000',
#        '$78,429,000,000', '$76,338,000,000', '$68,448,000,000',
#        '$64,699,000,000', '$61,506,000,000', '$54,912,000,000',
#        '$54,455,000,000', '$52,023,000,000', '$44,692,000,000',
# ...

# %%
#Eliminando las "," en las columnas requeridas. En la 4 también se elimina "$"
tabla2['Kw'] = tabla2['Kw'].astype(str).str.strip().str.replace(r',', '', regex=True)
tabla3['Btu/Person'] = tabla3['Btu/Person'].astype(str).str.strip().str.replace(r',', '', regex=True)
tabla4['Value'] = tabla4['Value'].astype(str).str.strip().str.replace(r',', '', regex=True).str.replace(r'^\$', '', regex=True)

# %%
#verificando que ya no hay caracteres que no sean números (ni "," ni "$")
pd.unique(tabla2.Kw[~tabla2.Kw.astype(str).str.contains(r'\d+\.\d+', regex=True)])
pd.unique(tabla3['Btu/Person'][~tabla3['Btu/Person'].astype(str).str.contains(r'\d+\.\d+', regex=True)])
pd.unique(tabla4.Value[~tabla4.Value.astype(str).str.contains(r'\d+\.\d+', regex=True)])
# Out:
# array(['3265000000000', '1160000000000', '822130000000', '597217000000',
#        '569544000000', '456700000000', '436769000000', '425554000000',
#        '409457000000', '365494000000', '318857000000', '231690000000',
#        '227760000000', '221944000000', '217261000000', '214544000000',
#        '185515000000', '149118000000', '148569000000', '141988000000',
#        '120600000000', '117551000000', '112968000000', '103239000000',
#        '96792000000', '95251000000', '92238000000', '90859000000',
#        '87048000000', '84875000000', '84154000000', '81242000000',
#        '80592000000', '78429000000', '76338000000', '68448000000',
#        '64699000000', '61506000000', '54912000000', '54455000000',
#        '52023000000', '44692000000', '44382000000', '44104000000',
#        '41485000000', '40270000000', '38612000000', '37194000000',
#        '35269000000', '34278000000', '29392000000', '27753000000',
#        '26445000000', '24910000000', '24381000000', '23834000000',
# ...

# %%
#transformar todos los valores a numeros en las columnas requeridas
tabla2.Kw=pd.to_numeric(tabla2.Kw,errors='coerce')
#comprobar que todo en Kw es número y hay 211 valores no nulos, es decir, que no hay NaN
tabla2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 211 non-null    object
#  1   Slug                 211 non-null    object
#  2   Kw                   211 non-null    int64
#  3   Date_Of_Information  211 non-null    int64
#  4   Ranking              211 non-null    int64
#  5   Region               211 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 10.0+ KB

# %%
#transformar todos los valores a numeros en las columnas requeridas
tabla3['Btu/Person']=pd.to_numeric(tabla3['Btu/Person'],errors='coerce')
#comprobar que todo en Btu/person es número y hay 195 valores no nulos, es decir, que no hay NaN
tabla3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 195 non-null    object
#  1   Slug                 195 non-null    object
#  2   Btu/Person           195 non-null    int64
#  3   Date_Of_Information  195 non-null    int64
#  4   Ranking              195 non-null    int64
#  5   Region               195 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 9.3+ KB

# %%
#transformar todos los valores a numeros en las columnas requeridas
tabla4.Value=pd.to_numeric(tabla4.Value,errors='coerce')
#comprobar que todo en Kw es número y hay 195 valores no nulos, es decir, que no hay NaN
tabla4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 195 non-null    object
#  1   Slug                 195 non-null    object
#  2   Value                195 non-null    int64
#  3   Date_Of_Information  195 non-null    int64
#  4   Ranking              195 non-null    int64
#  5   Region               195 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 9.3+ KB

# %%
#Elementos que tiene la tabla 3 que no tiene 4 guiándonos con la columna slug
tabla3menos4=set(tabla3.Slug)-set(tabla4.Slug)
tabla3menos4
# Out:
# {'american-samoa',
#  'bermuda',
#  'british-virgin-islands',
#  'guam',
#  'kiribati',
#  'korea-north',
#  'puerto-rico'}

# %%
#Elementos que tiene la tabla 4 que no tiene 3 guiándonos con la columna slug
tabla4menos3=set(tabla4.Slug)-set(tabla3.Slug)
tabla4menos3
# Out:
# {'anguilla',
#  'iceland',
#  'micronesia-federated-states-of',
#  'montserrat',
#  'palau',
#  'san-marino',
#  'trinidad-and-tobago'}

# %%
# !pip install thefuzz

# %%
from thefuzz import process as fz
[(c,fz.extractOne(c,tabla3menos4)) for c in sorted(tabla4menos3)]
# Out:
# [('anguilla', ('guam', 50)),
#  ('iceland', ('british-virgin-islands', 64)),
#  ('micronesia-federated-states-of', ('puerto-rico', 47)),
#  ('montserrat', ('korea-north', 38)),
#  ('palau', ('puerto-rico', 51)),
#  ('san-marino', ('american-samoa', 55)),
#  ('trinidad-and-tobago', ('kiribati', 43))]

# %%
#como las posibles opciones no presentan un % de similitud significativo, no se podrán recuperar datos en el merge 3-4
tabla34=tabla3.merge(tabla4,left_on='Slug', right_on='Slug')
tabla34
# Out:
#                                 Name_x                              Slug  \
# 0                                Qatar                             qatar
# 1                            Singapore                         singapore
# 2                              Bahrain                           bahrain
# 3                 United Arab Emirates              united-arab-emirates
# 4                               Brunei                            brunei
# ..                                 ...                               ...
# 183                               Chad                              chad
# 184  Congo, Democratic Republic of the  congo-democratic-republic-of-the
# 185           Central African Republic          central-african-republic
# 186                            Burundi                           burundi
# 187                            Somalia                           somalia
#
#      Btu/Person  Date_Of_Information_x  Ranking_x                 Region_x  \
# ...

# %%
#Se observa que las columnas irrelevantes son ranking y date of information.
#Además, si es que todos los elementos de la columna Name y Region son iguales, una de cada una también se puede eliminar
son_iguales_name = (tabla34['Name_x'] == tabla34['Name_y']).all()
if son_iguales_name:
    print("Se puede borrar una de las dos columnas")
else:
    print("No se pueden borrar una de las dos columnas")
# Out:
# Se puede borrar una de las dos columnas

# %%
son_iguales_region = (tabla34['Region_x'] == tabla34['Region_y']).all()
if son_iguales_region:
    print("Se puede borrar una de las dos columnas")
else:
    print("No se pueden borrar una de las dos columnas")
# Out:
# Se puede borrar una de las dos columnas

# %%
#se procede a borrar las columnas innecesarias y las 2 repetidas
tabla34.drop(['Ranking_x','Region_y','Ranking_y','Name_y','Date_Of_Information_x','Date_Of_Information_y'], axis=1, inplace=True)
tabla34
# Out:
#                                 Name_x                              Slug  \
# 0                                Qatar                             qatar
# 1                            Singapore                         singapore
# 2                              Bahrain                           bahrain
# 3                 United Arab Emirates              united-arab-emirates
# 4                               Brunei                            brunei
# ..                                 ...                               ...
# 183                               Chad                              chad
# 184  Congo, Democratic Republic of the  congo-democratic-republic-of-the
# 185           Central African Republic          central-african-republic
# 186                            Burundi                           burundi
# 187                            Somalia                           somalia
#
#      Btu/Person                 Region_x         Value
# ...

# %%
#Repetir proceso para el merge 12
#Elementos que tiene la tabla 1 que no tiene 2 guiándonos con la columna slug
tabla1menos2=set(tabla1.Slug)-set(tabla2.Slug)
tabla1menos2
# Out:
# {'andorra',
#  'anguilla',
#  'curacao',
#  'liechtenstein',
#  'marshall-islands',
#  'micronesia-federated-states-of',
#  'monaco',
#  'palau',
#  'san-marino'}

# %%
#Elementos que tiene la tabla 2 que no tiene 1 guiándonos con la columna slug
tabla2menos1=set(tabla2.Slug)-set(tabla1.Slug)
tabla2menos1
# Out:
# {'american-samoa',
#  'bosnia-and-herzegovina',
#  'cuba',
#  'equatorial-guinea',
#  'eritrea',
#  'falkland-islands-islas-malvinas',
#  'french-polynesia',
#  'gibraltar',
#  'guam',
#  'korea-north',
#  'kosovo',
#  'libya',
#  'montenegro',
#  'new-caledonia',
#  'niue',
#  'north-macedonia',
#  'saint-helena-ascension-and-tristan-da-cunha',
#  'saint-pierre-and-miquelon',
#  'sudan',
#  'syria',
#  'taiwan',
#  'virgin-islands',
#  'yemen'}

# %%
from thefuzz import process as fz
[(c,fz.extractOne(c,tabla1menos2)) for c in sorted(tabla2menos1)]
# Out:
# [('american-samoa', ('monaco', 60)),
#  ('bosnia-and-herzegovina', ('andorra', 53)),
#  ('cuba', ('curacao', 68)),
#  ('equatorial-guinea', ('palau', 54)),
#  ('eritrea', ('micronesia-federated-states-of', 51)),
#  ('falkland-islands-islas-malvinas', ('marshall-islands', 86)),
#  ('french-polynesia', ('micronesia-federated-states-of', 48)),
#  ('gibraltar', ('palau', 54)),
#  ('guam', ('anguilla', 50)),
#  ('korea-north', ('andorra', 51)),
#  ('kosovo', ('micronesia-federated-states-of', 36)),
#  ('libya', ('liechtenstein', 51)),
#  ('montenegro', ('monaco', 60)),
#  ('new-caledonia', ('monaco', 54)),
#  ('niue', ('liechtenstein', 51)),
#  ('north-macedonia', ('monaco', 60)),
#  ('saint-helena-ascension-and-tristan-da-cunha', ('andorra', 57)),
#  ('saint-pierre-and-miquelon', ('san-marino', 51)),
#  ('sudan', ('san-marino', 68)),
#  ('syria', ('micronesia-federated-states-of', 54)),
#  ('taiwan', ('liechtenstein', 54)),
#  ('virgin-islands', ('marshall-islands', 63)),
# ...

# %%
#como las posibles opciones no presentan un % de similitud significativo (salvo islas marshall-islas malvinas, pero no son iguales), no se podrán recuperar datos en el merge 1-2
tabla12=tabla1.merge(tabla2,left_on='Slug', right_on='Slug')
tabla12
# Out:
#                Name_x              Slug  %_Of_Gdp  Date_Of_Information_x  \
# 0     Solomon Islands   solomon-islands      12.8                   2020
# 1            Kiribati          kiribati      12.4                   2019
# 2           Greenland         greenland      10.2                   2019
# 3             Bolivia           bolivia       9.8                   2020
# 4             Namibia           namibia       9.6                   2021
# ..                ...               ...       ...                    ...
# 183             Haiti             haiti       1.4                   2020
# 184  Papua New Guinea  papua-new-guinea       1.4                   2020
# 185         Venezuela         venezuela       1.3                   2017
# 186           Nigeria           nigeria       0.5                   2013
# 187           Somalia           somalia       0.3                   2019
#
#      Ranking_x                           Region_x            Name_y        Kw  \
# ...

# %%
#Se observa que las columnas irrelevantes son ranking y date of information.
#Además, si es que todos los elementos de la columna Name y Region son iguales, una de cada una también se puede eliminar
son_iguales_name = (tabla12['Name_x'] == tabla12['Name_y']).all()
if son_iguales_name:
    print("Se puede borrar una de las dos columnas")
else:
    print("No se pueden borrar una de las dos columnas")
# Out:
# Se puede borrar una de las dos columnas

# %%
#Se observa que las columnas irrelevantes son ranking y date of information.
#Además, si es que todos los elementos de la columna Name y Region son iguales, una de cada una también se puede eliminar
son_iguales_name = (tabla12['Region_x'] == tabla12['Region_y']).all()
if son_iguales_name:
    print("Se puede borrar una de las dos columnas")
else:
    print("No se pueden borrar una de las dos columnas")
# Out:
# Se puede borrar una de las dos columnas

# %%
#se procede a borrar las columnas innecesarias y las 2 repetidas
tabla12.drop(['Ranking_x','Region_y','Ranking_y','Name_y','Date_Of_Information_x','Date_Of_Information_y'], axis=1, inplace=True)
tabla12
# Out:
#                Name_x              Slug  %_Of_Gdp  \
# 0     Solomon Islands   solomon-islands      12.8
# 1            Kiribati          kiribati      12.4
# 2           Greenland         greenland      10.2
# 3             Bolivia           bolivia       9.8
# 4             Namibia           namibia       9.6
# ..                ...               ...       ...
# 183             Haiti             haiti       1.4
# 184  Papua New Guinea  papua-new-guinea       1.4
# 185         Venezuela         venezuela       1.3
# 186           Nigeria           nigeria       0.5
# 187           Somalia           somalia       0.3
#
#                               Region_x        Kw
# 0                Australia and Oceania     37000
# 1                Australia and Oceania     12000
# 2                        North America    190000
# 3                        South America   4375000
# 4                               Africa    646000
# ..                                 ...       ...
# ...

# %%
#Repetir proceso para el merge 1234
#Elementos que tiene la tabla 12 que no tiene 34 guiándonos con la columna slug
tabla12menos34=set(tabla12.Slug)-set(tabla34.Slug)
tabla12menos34
# Out:
# {'bermuda',
#  'british-virgin-islands',
#  'cook-islands',
#  'faroe-islands',
#  'greenland',
#  'iceland',
#  'kiribati',
#  'montserrat',
#  'nauru',
#  'puerto-rico',
#  'trinidad-and-tobago',
#  'turks-and-caicos-islands'}

# %%
#Elementos que tiene la tabla 34 que no tiene 12 guiándonos con la columna slug
tabla34menos12=set(tabla34.Slug)-set(tabla12.Slug)
tabla34menos12
# Out:
# {'bosnia-and-herzegovina',
#  'cuba',
#  'equatorial-guinea',
#  'eritrea',
#  'kosovo',
#  'libya',
#  'montenegro',
#  'north-macedonia',
#  'sudan',
#  'syria',
#  'taiwan',
#  'yemen'}

# %%
from thefuzz import process as fz
[(c,fz.extractOne(c,tabla12menos34)) for c in sorted(tabla34menos12)]
# Out:
# [('bosnia-and-herzegovina', ('nauru', 51)),
#  ('cuba', ('bermuda', 51)),
#  ('equatorial-guinea', ('bermuda', 49)),
#  ('eritrea', ('puerto-rico', 51)),
#  ('kosovo', ('turks-and-caicos-islands', 43)),
#  ('libya', ('kiribati', 54)),
#  ('montenegro', ('montserrat', 60)),
#  ('north-macedonia', ('nauru', 45)),
#  ('sudan', ('trinidad-and-tobago', 54)),
#  ('syria', ('kiribati', 54)),
#  ('taiwan', ('trinidad-and-tobago', 54)),
#  ('yemen', ('greenland', 54))]

# %%
#como las posibles opciones no presentan un % de similitud significativo, no se podrán recuperar datos en el merge 12-34
tabla1234=tabla12.merge(tabla34,left_on='Slug', right_on='Slug')
tabla1234
# Out:
#              Name_x_x              Slug  %_Of_Gdp  \
# 0     Solomon Islands   solomon-islands      12.8
# 1             Bolivia           bolivia       9.8
# 2             Namibia           namibia       9.6
# 3        Sierra Leone      sierra-leone       9.1
# 4              Belize            belize       8.7
# ..                ...               ...       ...
# 171             Haiti             haiti       1.4
# 172  Papua New Guinea  papua-new-guinea       1.4
# 173         Venezuela         venezuela       1.3
# 174           Nigeria           nigeria       0.5
# 175           Somalia           somalia       0.3
#
#                             Region_x_x        Kw          Name_x_y  \
# 0                Australia and Oceania     37000   Solomon Islands
# 1                        South America   4375000           Bolivia
# 2                               Africa    646000           Namibia
# 3                               Africa    149000      Sierra Leone
# ...

# %%
#Si es que todos los elementos de la columna Name y Region son iguales, una de cada una también se puede eliminar
son_iguales_name = (tabla1234['Region_x_x'] == tabla1234['Region_x_y']).all()
if son_iguales_name:
    print("Se puede borrar una de las dos columnas")
else:
    print("No se pueden borrar una de las dos columnas")
# Out:
# Se puede borrar una de las dos columnas

# %%
#Si es que todos los elementos de la columna Name y Region son iguales, una de cada una también se puede eliminar
son_iguales_name = (tabla1234['Region_x_x'] == tabla1234['Region_x_y']).all()
if son_iguales_name:
    print("Se puede borrar una de las dos columnas")
else:
    print("No se pueden borrar una de las dos columnas")
# Out:
# Se puede borrar una de las dos columnas

# %%
#se procede a borrar las columnas repetidas
tabla1234.drop(['Region_x_y','Name_x_y'], axis=1, inplace=True)
tabla1234
# Out:
#              Name_x_x              Slug  %_Of_Gdp  \
# 0     Solomon Islands   solomon-islands      12.8
# 1             Bolivia           bolivia       9.8
# 2             Namibia           namibia       9.6
# 3        Sierra Leone      sierra-leone       9.1
# 4              Belize            belize       8.7
# ..                ...               ...       ...
# 171             Haiti             haiti       1.4
# 172  Papua New Guinea  papua-new-guinea       1.4
# 173         Venezuela         venezuela       1.3
# 174           Nigeria           nigeria       0.5
# 175           Somalia           somalia       0.3
#
#                             Region_x_x        Kw  Btu/Person        Value
# 0                Australia and Oceania     37000     5655000    688220000
# 1                        South America   4375000    29340000     87100000
# 2                               Africa    646000    21734000   3356000000
# ...

# %%
#Renombrando las columnas
tabla1234=tabla1234.rename(columns={'Name_x_x':'Country', '%_Of_Gdp':'%_of_GDP','Kw':'kW', 'Region_x_x':'Region',})
tabla1234
# Out:
#               Country              Slug  %_of_GDP  \
# 0     Solomon Islands   solomon-islands      12.8
# 1             Bolivia           bolivia       9.8
# 2             Namibia           namibia       9.6
# 3        Sierra Leone      sierra-leone       9.1
# 4              Belize            belize       8.7
# ..                ...               ...       ...
# 171             Haiti             haiti       1.4
# 172  Papua New Guinea  papua-new-guinea       1.4
# 173         Venezuela         venezuela       1.3
# 174           Nigeria           nigeria       0.5
# 175           Somalia           somalia       0.3
#
#                                 Region        kW  Btu/Person        Value
# 0                Australia and Oceania     37000     5655000    688220000
# 1                        South America   4375000    29340000     87100000
# 2                               Africa    646000    21734000   3356000000
# ...

# %%
#todos los Dtype son coherentes
tabla1234.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Country     176 non-null    object
#  1   Slug        176 non-null    object
#  2   %_of_GDP    176 non-null    float64
#  3   Region      176 non-null    object
#  4   kW          176 non-null    int64
#  5   Btu/Person  176 non-null    int64
#  6   Value       176 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 9.8+ KB

# %%
#Para el paso 4, reportar promedio mínimo y máximo por región
varsAggregated=['%_of_GDP','kW','Btu/Person','Value']
funciones=['mean','min','max']
tabla_min_max_mean=tabla1234.groupby('Region')[varsAggregated].agg(funciones)
#Por si queremos exportar el trabajo a otra aplicacion:
#tablaregion.columns=['_'.join(col) for col in tablaregion.columns.to_flat_index()]
tabla_min_max_mean
# Out:
#                                    %_of_GDP                       kW  \
#                                        mean  min   max          mean
# Region
# Africa                             4.268000  0.3   9.6  4.619820e+06
# Australia and Oceania              6.314286  2.2  12.8  1.706100e+07
# Central America and the Caribbean  4.555000  1.4   8.7  1.580500e+06
# Central Asia                       4.333333  2.8   6.2  4.239578e+07
# East and Southeast Asia            3.633333  1.4   6.3  2.108446e+08
# Europe                             5.151429  3.1   7.2  4.027509e+07
# Middle East                        4.528571  1.7   7.8  3.381729e+07
# North America                      5.200000  4.3   6.1  5.008580e+08
# South America                      4.808333  1.3   9.8  3.550408e+07
# South Asia                         3.850000  1.9   7.0  7.211612e+07
#
#                                                             Btu/Person  \
# ...

# %%
#Proseguir con el paso 5, discretización
# !pip install mapclassify
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 kB 2.5 MB/s eta 0:00:00
# ...

# %%
tabla1234
# Out:
#               Country              Slug  %_of_GDP  \
# 0     Solomon Islands   solomon-islands      12.8
# 1             Bolivia           bolivia       9.8
# 2             Namibia           namibia       9.6
# 3        Sierra Leone      sierra-leone       9.1
# 4              Belize            belize       8.7
# ..                ...               ...       ...
# 171             Haiti             haiti       1.4
# 172  Papua New Guinea  papua-new-guinea       1.4
# 173         Venezuela         venezuela       1.3
# 174           Nigeria           nigeria       0.5
# 175           Somalia           somalia       0.3
#
#                                 Region        kW  Btu/Person        Value
# 0                Australia and Oceania     37000     5655000    688220000
# 1                        South America   4375000    29340000     87100000
# 2                               Africa    646000    21734000   3356000000
# ...

# %%
#Iniciar en orden partiendo de %gdp, creando 5 intervalos
import mapclassify
import numpy as np
K=5
#Se usará FisherJenks al ser el más eficiente
intervaloGDP=mapclassify.FisherJenks(tabla1234['%_of_GDP'], k=K)
intervalokW=mapclassify.FisherJenks(tabla1234['kW'], k=K)
intervaloBTU=mapclassify.FisherJenks(tabla1234['Btu/Person'], k=K)
intervaloVALUE=mapclassify.FisherJenks(tabla1234['Value'], k=K)

# %%
#Se agregan los intervalos creados como columna
tabla1234['Intervalo_GDP']=intervaloGDP.yb
tabla1234['Intervalo_kW']=intervalokW.yb
tabla1234['Intervalo_BTU']=intervaloBTU.yb
tabla1234['Intervalo_VALUE']=intervaloVALUE.yb
tabla1234
# Out:
#               Country              Slug  %_of_GDP  \
# 0     Solomon Islands   solomon-islands      12.8
# 1             Bolivia           bolivia       9.8
# 2             Namibia           namibia       9.6
# 3        Sierra Leone      sierra-leone       9.1
# 4              Belize            belize       8.7
# ..                ...               ...       ...
# 171             Haiti             haiti       1.4
# 172  Papua New Guinea  papua-new-guinea       1.4
# 173         Venezuela         venezuela       1.3
# 174           Nigeria           nigeria       0.5
# 175           Somalia           somalia       0.3
#
#                                 Region        kW  Btu/Person        Value  \
# 0                Australia and Oceania     37000     5655000    688220000
# 1                        South America   4375000    29340000     87100000
# 2                               Africa    646000    21734000   3356000000
# ...

# %%
#quitando la columna slug pues ya no será de uso
tabla1234.drop(['Slug'], axis=1, inplace=True)

# %%
#reacomodando la tabla
reordenar=['Country','Region','%_of_GDP','Intervalo_GDP','kW','Intervalo_kW','Btu/Person','Intervalo_BTU','Value','Intervalo_VALUE']
tabla1234=tabla1234.reindex(columns=reordenar)
tabla1234
# Out:
#               Country                             Region  %_of_GDP  \
# 0     Solomon Islands              Australia and Oceania      12.8
# 1             Bolivia                      South America       9.8
# 2             Namibia                             Africa       9.6
# 3        Sierra Leone                             Africa       9.1
# 4              Belize  Central America and the Caribbean       8.7
# ..                ...                                ...       ...
# 171             Haiti  Central America and the Caribbean       1.4
# 172  Papua New Guinea            East and Southeast Asia       1.4
# 173         Venezuela                      South America       1.3
# 174           Nigeria                             Africa       0.5
# 175           Somalia                             Africa       0.3
#
#      Intervalo_GDP        kW  Intervalo_kW  Btu/Person  Intervalo_BTU  \
# 0                4     37000             0     5655000              0
# ...

# %%
#guardar la tabla en pickle
tabla1234.to_pickle("tabla.pkl")
dfPickle=pd.read_pickle("tabla.pkl")
dfPickle.info()
#se observa además que todos los Dtype son coherentes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          176 non-null    object
#  1   Region           176 non-null    object
#  2   %_of_GDP         176 non-null    float64
#  3   Intervalo_GDP    176 non-null    int64
#  4   kW               176 non-null    int64
#  5   Intervalo_kW     176 non-null    int64
#  6   Btu/Person       176 non-null    int64
#  7   Intervalo_BTU    176 non-null    int64
#  8   Value            176 non-null    int64
#  9   Intervalo_VALUE  176 non-null    int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 13.9+ KB
